# %% [markdown]
# # Comparison of satellite images and learned embeddings for land cover mapping in the Brazilian Amazon

# %% [markdown]
# ## Procedure
# 1) Train model on Sentinel 2 images using gt land cover maps as GT labels
# 2) Model AE embeddings using the same GT labels
#     a) One DL model
#     b) One without DL
# 3) Compare results (precision, accuracy, loss function...)
# #### Optional :
# design and implement a DL to combine Sentinel 2 and AE embeddings.
#
# #### Overall idea of the project :
# Show that with only embeddings (that resume images with significant features) we obtain good results
# -> advantages are less complexity of algorithms etc....
#
# Results will be loaded and plotted here

# %%
import numpy as np
import sys
print(sys.executable)

from skimage.io import imsave, imread
import matplotlib.pyplot as plt
#print different images to see what it looks like 
label_image = imread('DATA/data/labels/test_010001.tif')

# TODO: Visualize the image using matplotlib
plt.imshow(label_image) #for 3D image 
plt.axis('off')
plt.show()
# Out:
# /home/gvander/ipeo_project/bin/python
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_833497/1328298650.py in ?()
#       4
#       5 from skimage.io import imsave, imread
#       6 import matplotlib.pyplot as plt
#       7 #print different images to see what it looks like
# ----> 8 label_image = imread('DATA/data/labels/test_010001.tif')
#       9
#      10 # TODO: Visualize the image using matplotlib
#      11 plt.imshow(label_image) #for 3D image
#
# ~/ipeo_project/lib/python3.10/site-packages/skimage/_shared/utils.py in ?(*args, **kwargs)
#     324                 elif self.new_name is not None:
#     325                     # Assign old value to new one
#     326                     kwargs[self.new_name] = deprecated_value
#     327
# --> 328             return func(*args, **kwargs)
#
# ...
